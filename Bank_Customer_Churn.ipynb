# %% [markdown]
# ***Title : Bank Customer Churn Model***

# %% [markdown]
# ***Objective : The objective of the Bank Customer Churn Model project is to predict whether a customer will leave the bank or not, utilizing various parameters.***

# %% [markdown]
# ***Data Source: https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Bank%20Churn%20Modelling.csv***

# %%
#Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Bank%20Churn%20Modelling.csv')
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  Num Of Products  Has Credit Card  Is Active Member  \
# 0       0.00                1                1                 1
# 1   83807.86                1                0                 1
# 2  159660.80                3                1                 0
# 3       0.00                2                0                 0
# 4  125510.82                1                1                 1
#
#    Estimated Salary  Churn
# 0         101348.88      1
# 1         112542.58      0
# 2         113931.57      1
# 3          93826.63      0
# 4          79084.10      0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17['CustomerId'].plot(kind='hist', bins=20, title='CustomerId')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['CreditScore'].plot(kind='hist', bins=20, title='CreditScore')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['Tenure'].plot(kind='hist', bins=20, title='Tenure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_21.groupby('Surname').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_22.groupby('Geography').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23.plot(kind='scatter', x='CustomerId', y='CreditScore', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24.plot(kind='scatter', x='CreditScore', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25.plot(kind='scatter', x='Age', y='Tenure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26.plot(kind='scatter', x='Tenure', y='Balance', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['CustomerId'].plot(kind='line', figsize=(8, 4), title='CustomerId')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['CreditScore'].plot(kind='line', figsize=(8, 4), title='CreditScore')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['Tenure'].plot(kind='line', figsize=(8, 4), title='Tenure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Geography'].value_counts()
#     for x_label, grp in _df_31.groupby('Surname')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Surname')
# _ = plt.ylabel('Geography')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_32['Surname'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_32, x='CustomerId', y='Surname', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_33['Geography'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_33, x='CustomerId', y='Geography', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_34['Surname'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_34, x='CreditScore', y='Surname', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_35['Geography'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_35, x='CreditScore', y='Geography', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerId        10000 non-null  int64
#  1   Surname           10000 non-null  object
#  2   CreditScore       10000 non-null  int64
#  3   Geography         10000 non-null  object
#  4   Gender            10000 non-null  object
#  5   Age               10000 non-null  int64
#  6   Tenure            10000 non-null  int64
#  7   Balance           10000 non-null  float64
#  8   Num Of Products   10000 non-null  int64
#  9   Has Credit Card   10000 non-null  int64
#  10  Is Active Member  10000 non-null  int64
#  11  Estimated Salary  10000 non-null  float64
#  12  Churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df.duplicated('CustomerId').sum()
# Out:
# 0

# %%
df=df.set_index('CustomerId')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Surname           10000 non-null  object
#  1   CreditScore       10000 non-null  int64
#  2   Geography         10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age               10000 non-null  int64
#  5   Tenure            10000 non-null  int64
#  6   Balance           10000 non-null  float64
#  7   Num Of Products   10000 non-null  int64
#  8   Has Credit Card   10000 non-null  int64
#  9   Is Active Member  10000 non-null  int64
#  10  Estimated Salary  10000 non-null  float64
#  11  Churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 1015.6+ KB

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288
# std       96.653299     10.487806      2.892174   62397.405202
# min      350.000000     18.000000      0.000000       0.000000
# 25%      584.000000     32.000000      3.000000       0.000000
# 50%      652.000000     37.000000      5.000000   97198.540000
# 75%      718.000000     44.000000      7.000000  127644.240000
# max      850.000000     92.000000     10.000000  250898.090000
#
#        Num Of Products  Has Credit Card  Is Active Member  Estimated Salary  \
# count     10000.000000      10000.00000      10000.000000      10000.000000
# mean          1.530200          0.70550          0.515100     100090.239881
# std           0.581654          0.45584          0.499797      57510.492818
# min           1.000000          0.00000          0.000000         11.580000
# 25%           1.000000          0.00000          0.000000      51002.110000
# 50%           1.000000          1.00000          1.000000     100193.915000
# 75%           2.000000          1.00000          1.000000     149388.247500
# max           4.000000          1.00000          1.000000     199992.480000
#
#               Churn
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['CreditScore'].plot(kind='hist', bins=20, title='CreditScore')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Tenure'].plot(kind='hist', bins=20, title='Tenure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Balance'].plot(kind='hist', bins=20, title='Balance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='CreditScore', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Age', y='Tenure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Tenure', y='Balance', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Balance', y='Num Of Products', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['CreditScore'].plot(kind='line', figsize=(8, 4), title='CreditScore')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Tenure'].plot(kind='line', figsize=(8, 4), title='Tenure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Balance'].plot(kind='line', figsize=(8, 4), title='Balance')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.describe(include='object')
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('Surname').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_13.groupby('Geography').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_14.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Geography'].value_counts()
#     for x_label, grp in _df_15.groupby('Surname')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Surname')
# _ = plt.ylabel('Geography')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Gender'].value_counts()
#     for x_label, grp in _df_16.groupby('Geography')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Geography')
# _ = plt.ylabel('Gender')

# %%
df.isnull().sum()
# Out:
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance             0
# Num Of Products     0
# Has Credit Card     0
# Is Active Member    0
# Estimated Salary    0
# Churn               0
# dtype: int64

# %% [markdown]
# ***Data Preprocessing: Encoding***

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df.replace({'Geography':{'France':2,'Germany':1,'Spain':0}},inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df.replace({'Gender':{'Male':0,'Female':1}},inplace=True)

# %%
df['Num Of Products'].value_counts()
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: Num Of Products, dtype: int64

# %%
df.replace({'Num Of Products':{1:0,2:1,3:1,4:1}},inplace=True)

# %%
df['Has Credit Card'].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: Has Credit Card, dtype: int64

# %%
df['Is Active Member'].value_counts()
# Out:
# 1    5151
# 0    4849
# Name: Is Active Member, dtype: int64

# %%
df.loc[(df['Balance']==0),'Churn'].value_counts()
# Out:
# 0    3117
# 1     500
# Name: Churn, dtype: int64

# %%
df['Zero Balance']=np.where(df['Balance']>0,1,0)

# %%
df['Zero Balance'].hist()
# Out:
# <Axes: >

# %%
df.groupby(['Churn','Geography']).count()
# Out:
#                  Surname  CreditScore  Gender   Age  Tenure  Balance  \
# Churn Geography
# 0     0             2064         2064    2064  2064    2064     2064
#       1             1695         1695    1695  1695    1695     1695
#       2             4204         4204    4204  4204    4204     4204
# 1     0              413          413     413   413     413      413
#       1              814          814     814   814     814      814
#       2              810          810     810   810     810      810
#
#                  Num Of Products  Has Credit Card  Is Active Member  \
# Churn Geography
# 0     0                     2064             2064              2064
#       1                     1695             1695              1695
#       2                     4204             4204              4204
# 1     0                      413              413               413
#       1                      814              814               814
#       2                      810              810               810
#
#                  Estimated Salary  Zero Balance
# Churn Geography
# 0     0                      2064          2064
#       1                      1695          1695
#       2                      4204          4204
# 1     0                       413           413
#       1                       814           814
#       2                       810           810

# %% [markdown]
# ***Define Label and Features***

# %%
df.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'Num Of Products', 'Has Credit Card', 'Is Active Member',
#        'Estimated Salary', 'Churn', 'Zero Balance'],
#       dtype='object')

# %% [markdown]
# ***Define Target Variable (y) and Feature Variables (X)***

# %%
x=df.drop(['Surname','Churn'],axis=1)

# %%
y=df['Churn']

# %%
x.shape,y.shape
# Out:
# ((10000, 11), (10000,))

# %%
df['Churn'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Churn, dtype: int64

# %%
sns.countplot(x='Churn',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ***Random Under Sampling***

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rs=RandomUnderSampler(random_state=2529)

# %%
x_rs,y_rs=rs.fit_resample(x,y)

# %%
x_rs.shape,y_rs.shape,x.shape,y.shape
# Out:
# ((4074, 11), (4074,), (10000, 11), (10000,))

# %%
y.value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Churn, dtype: int64

# %%
y_rs.value_counts()
# Out:
# 0    2037
# 1    2037
# Name: Churn, dtype: int64

# %%
y_rs.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ro=RandomOverSampler(random_state=2529)

# %%
x_ro,y_ro=ro.fit_resample(x,y)

# %%
x_ro.shape,y_ro.shape,x.shape,y.shape
# Out:
# ((15926, 11), (15926,), (10000, 11), (10000,))

# %%
y.value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Churn, dtype: int64

# %%
y_ro.value_counts()
# Out:
# 1    7963
# 0    7963
# Name: Churn, dtype: int64

# %%
y_ro.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ***Train Test Split***

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ***Split Original Data***

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=25)

# %% [markdown]
# ***Split Random Under Sample Data***

# %%
x_train_rs,x_test_rs,y_train_rs,y_test_rs=train_test_split(x_rs,y_rs,test_size=0.3,random_state=25)

# %% [markdown]
# ***Split Random Over Sample Data***

# %%
x_train_ro,x_test_ro,y_train_ro,y_test_ro=train_test_split(x_ro,y_ro,test_size=0.3,random_state=25)

# %% [markdown]
# ***Standardize Original Data***

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %% [markdown]
# ***Standardize Original Data***

# %%
x_train[['CreditScore','Age','Tenure','Balance','Estimated Salary']]=sc.fit_transform(x_train[['CreditScore','Age','Tenure','Balance','Estimated Salary']])

# %%
x_test[['CreditScore','Age','Tenure','Balance','Estimated Salary']]=sc.fit_transform(x_test[['CreditScore','Age','Tenure','Balance','Estimated Salary']])

# %% [markdown]
# ***Standardize Random Under Sample Data***

# %%
x_train_rs[['CreditScore','Age','Tenure','Balance','Estimated Salary']]=sc.fit_transform(x_train_rs[['CreditScore','Age','Tenure','Balance','Estimated Salary']])

# %%
x_test_rs[['CreditScore','Age','Tenure','Balance','Estimated Salary']]=sc.fit_transform(x_test_rs[['CreditScore','Age','Tenure','Balance','Estimated Salary']])

# %% [markdown]
# ***Standardize Random Over Sample Data***

# %%
x_train_ro[['CreditScore','Age','Tenure','Balance','Estimated Salary']]=sc.fit_transform(x_train_ro[['CreditScore','Age','Tenure','Balance','Estimated Salary']])

# %%
x_test_ro[['CreditScore','Age','Tenure','Balance','Estimated Salary']]=sc.fit_transform(x_test_ro[['CreditScore','Age','Tenure','Balance','Estimated Salary']])

# %% [markdown]
# ***Support Vector Machine Classifier***

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)

# %% [markdown]
# ***Model Accuracy***

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[2374,   45],
#        [ 421,  160]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      2419
#            1       0.78      0.28      0.41       581
#
#     accuracy                           0.84      3000
#    macro avg       0.81      0.63      0.66      3000
# weighted avg       0.84      0.84      0.81      3000

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'C':[0.1,1,1.0],
            'gamma':[1,0.1,0.01],
            'kernel':['rbf'],
            'class_weight':['balanced']}

# %%
grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=2,cv=2)
grid.fit(x_train,y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   1.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.0s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.2s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.0s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END ..C=1.0, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.2s
# [CV] END ..C=1.0, class_weight=balanced, gamma=1, kernel=rbf; total time=   2.2s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.1s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.3s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   1.8s
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 1.0], 'class_weight': ['balanced'],
#                          'gamma': [1, 0.1, 0.01], 'kernel': ['rbf']},
#              verbose=2)

# %%
print(grid.best_estimator_)
# Out:
# SVC(C=0.1, class_weight='balanced', gamma=1)

# %%
grid_predictions=grid.predict(x_test)

# %%
confusion_matrix(y_test,grid_predictions)
# Out:
# array([[2019,  400],
#        [ 258,  323]])

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      2419
#            1       0.45      0.56      0.50       581
#
#     accuracy                           0.78      3000
#    macro avg       0.67      0.70      0.68      3000
# weighted avg       0.80      0.78      0.79      3000

# %% [markdown]
# ***Model With Random Under Sampling***

# %%
svc_rs=SVC()

# %%
svc_rs.fit(x_train_rs,y_train_rs)
# Out:
# SVC()

# %%
y_pred_rs=svc_rs.predict(x_test_rs)

# %% [markdown]
# ***Model Accuracy***

# %%
confusion_matrix(y_test_rs,y_pred_rs)
# Out:
# array([[483, 120],
#        [172, 448]])

# %%
print(classification_report(y_test_rs,y_pred_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       603
#            1       0.79      0.72      0.75       620
#
#     accuracy                           0.76      1223
#    macro avg       0.76      0.76      0.76      1223
# weighted avg       0.76      0.76      0.76      1223

# %% [markdown]
# ***Hyperparameter Tunning***

# %%
param_grid={'C':[0.1,1,1.0],
            'gamma':[1,0.1,0.01],
            'kernel':['rbf'],
            'class_weight':['balanced']}

# %%
grid_rs=GridSearchCV(SVC(),param_grid,refit=True,verbose=2,cv=2)
grid_rs.fit(x_train_rs,y_train_rs)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.6s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.7s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.5s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.5s
# [CV] END ..C=1.0, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END ..C=1.0, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   0.2s
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 1.0], 'class_weight': ['balanced'],
#                          'gamma': [1, 0.1, 0.01], 'kernel': ['rbf']},
#              verbose=2)

# %%
print(grid_rs.best_estimator_)
# Out:
# SVC(C=0.1, class_weight='balanced', gamma=0.1)

# %%
grid_predictions_rs=grid_rs.predict(x_test_rs)

# %%
confusion_matrix(y_test_rs,grid_predictions_rs)
# Out:
# array([[458, 145],
#        [178, 442]])

# %%
print(classification_report(y_test_rs,grid_predictions_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       603
#            1       0.75      0.71      0.73       620
#
#     accuracy                           0.74      1223
#    macro avg       0.74      0.74      0.74      1223
# weighted avg       0.74      0.74      0.74      1223

# %% [markdown]
# ***Model With Random Over Sampling***

# %%
svc_ro=SVC()

# %%
svc_ro.fit(x_train_ro,y_train_ro)
# Out:
# SVC()

# %%
y_pred_ro=svc_ro.predict(x_test_ro)

# %% [markdown]
# ***Model Accuracy***

# %%
confusion_matrix(y_test_ro,y_pred_ro)
# Out:
# array([[1854,  572],
#        [ 551, 1801]])

# %%
print(classification_report(y_test_ro,y_pred_ro))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77      2426
#            1       0.76      0.77      0.76      2352
#
#     accuracy                           0.76      4778
#    macro avg       0.76      0.76      0.76      4778
# weighted avg       0.77      0.76      0.76      4778

# %% [markdown]
# ***Hyperparameter Tunning***

# %%
param_grid={'C':[0.1,1,1.0],
            'gamma':[1,0.1,0.01],
            'kernel':['rbf'],
            'class_weight':['balanced']}

# %%
grid_ro=GridSearchCV(SVC(),param_grid,refit=True,verbose=2,cv=2)
grid_ro.fit(x_train_ro,y_train_ro)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   6.2s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   4.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   7.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   6.1s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   3.4s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   8.3s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   4.1s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   4.1s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   7.5s
# [CV] END .C=1, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   4.8s
# [CV] END ..C=1.0, class_weight=balanced, gamma=1, kernel=rbf; total time=   4.0s
# [CV] END ..C=1.0, class_weight=balanced, gamma=1, kernel=rbf; total time=   6.0s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   5.8s
# [CV] END C=1.0, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   3.6s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.7s
# [CV] END C=1.0, class_weight=balanced, gamma=0.01, kernel=rbf; total time=   2.6s
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 1.0], 'class_weight': ['balanced'],
#                          'gamma': [1, 0.1, 0.01], 'kernel': ['rbf']},
#              verbose=2)

# %%
print(grid_ro.best_estimator_)
# Out:
# SVC(C=1, class_weight='balanced', gamma=1)

# %%
grid_predictions_ro=grid_ro.predict(x_test_ro)

# %%
confusion_matrix(y_test_ro,grid_predictions_ro)
# Out:
# array([[2077,  349],
#        [ 190, 2162]])

# %%
print(classification_report(y_test_ro,grid_predictions_ro))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      2426
#            1       0.86      0.92      0.89      2352
#
#     accuracy                           0.89      4778
#    macro avg       0.89      0.89      0.89      4778
# weighted avg       0.89      0.89      0.89      4778

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      2419
#            1       0.78      0.28      0.41       581
#
#     accuracy                           0.84      3000
#    macro avg       0.81      0.63      0.66      3000
# weighted avg       0.84      0.84      0.81      3000

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      2419
#            1       0.45      0.56      0.50       581
#
#     accuracy                           0.78      3000
#    macro avg       0.67      0.70      0.68      3000
# weighted avg       0.80      0.78      0.79      3000

# %%
print(classification_report(y_test_rs,y_pred_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       603
#            1       0.79      0.72      0.75       620
#
#     accuracy                           0.76      1223
#    macro avg       0.76      0.76      0.76      1223
# weighted avg       0.76      0.76      0.76      1223

# %%
print(classification_report(y_test_rs,grid_predictions_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74       603
#            1       0.75      0.71      0.73       620
#
#     accuracy                           0.74      1223
#    macro avg       0.74      0.74      0.74      1223
# weighted avg       0.74      0.74      0.74      1223

# %%
print(classification_report(y_test_ro,y_pred_ro))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77      2426
#            1       0.76      0.77      0.76      2352
#
#     accuracy                           0.76      4778
#    macro avg       0.76      0.76      0.76      4778
# weighted avg       0.77      0.76      0.76      4778

# %%
print(classification_report(y_test_ro,grid_predictions_ro)) # More Accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      2426
#            1       0.86      0.92      0.89      2352
#
#     accuracy                           0.89      4778
#    macro avg       0.89      0.89      0.89      4778
# weighted avg       0.89      0.89      0.89      4778

# %% [markdown]
# ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ***Model With Original Data***

# %%
classifier = LogisticRegression(random_state=42)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = classifier.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2331,   88],
#        [ 450,  131]])

# %%
print(classification_report(y_test, y_pred)) # More Accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      2419
#            1       0.60      0.23      0.33       581
#
#     accuracy                           0.82      3000
#    macro avg       0.72      0.59      0.61      3000
# weighted avg       0.79      0.82      0.79      3000

# %% [markdown]
# ***Model With Random Under Sample Data***

# %%
classifier_rs = LogisticRegression(random_state=42)
classifier_rs.fit(x_train_rs, y_train_rs)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred_rs = classifier_rs.predict(x_test_rs)

# %%
confusion_matrix(y_test_rs, y_pred_rs)
# Out:
# array([[446, 157],
#        [172, 448]])

# %%
print(classification_report(y_test_rs, y_pred_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73       603
#            1       0.74      0.72      0.73       620
#
#     accuracy                           0.73      1223
#    macro avg       0.73      0.73      0.73      1223
# weighted avg       0.73      0.73      0.73      1223

# %% [markdown]
# ***Model With Random Over Sample Data***

# %%
classifier_ro = LogisticRegression(random_state=42)
classifier_ro.fit(x_train_ro, y_train_ro)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred_ro = classifier_ro.predict(x_test_ro)

# %%
confusion_matrix(y_test_ro, y_pred_ro)
# Out:
# array([[1727,  699],
#        [ 690, 1662]])

# %%
print(classification_report(y_test_ro, y_pred_ro))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71      2426
#            1       0.70      0.71      0.71      2352
#
#     accuracy                           0.71      4778
#    macro avg       0.71      0.71      0.71      4778
# weighted avg       0.71      0.71      0.71      4778

# %% [markdown]
# ***Decision Tree Classifier***

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(random_state=42)
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = classifier.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2043,  376],
#        [ 337,  244]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      2419
#            1       0.39      0.42      0.41       581
#
#     accuracy                           0.76      3000
#    macro avg       0.63      0.63      0.63      3000
# weighted avg       0.77      0.76      0.77      3000

# %% [markdown]
# ***Model With Random Under Sample Data***

# %%
classifier_rs = DecisionTreeClassifier(random_state=42)
classifier_rs.fit(x_train_rs, y_train_rs)
y_pred_rs = classifier_rs.predict(x_test_rs)

# %%
confusion_matrix(y_test_rs, y_pred_rs)
# Out:
# array([[393, 210],
#        [209, 411]])

# %%
print(classification_report(y_test_rs, y_pred_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65       603
#            1       0.66      0.66      0.66       620
#
#     accuracy                           0.66      1223
#    macro avg       0.66      0.66      0.66      1223
# weighted avg       0.66      0.66      0.66      1223

# %% [markdown]
# ***Model With Random Over Sample Data***

# %%
classifier_ro = DecisionTreeClassifier(random_state=42)
classifier_ro.fit(x_train_ro, y_train_ro)
y_pred_ro = classifier_ro.predict(x_test_ro)

# %%
confusion_matrix(y_test_ro, y_pred_ro)
# Out:
# array([[1978,  448],
#        [ 237, 2115]])

# %%
print(classification_report(y_test_ro, y_pred_ro)) # High Accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      2426
#            1       0.83      0.90      0.86      2352
#
#     accuracy                           0.86      4778
#    macro avg       0.86      0.86      0.86      4778
# weighted avg       0.86      0.86      0.86      4778

# %% [markdown]
# ***Random Forest Classifier***

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=100, random_state=42)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = classifier.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2328,   91],
#        [ 369,  212]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      2419
#            1       0.70      0.36      0.48       581
#
#     accuracy                           0.85      3000
#    macro avg       0.78      0.66      0.69      3000
# weighted avg       0.83      0.85      0.83      3000

# %% [markdown]
# ***Model With Random Under Sample Data***

# %%
classifier_rs = RandomForestClassifier(n_estimators=100, random_state=42)
classifier_rs.fit(x_train_rs, y_train_rs)
y_pred_rs = classifier_rs.predict(x_test_rs)

# %%
confusion_matrix(y_test_rs, y_pred_rs)
# Out:
# array([[463, 140],
#        [172, 448]])

# %%
print(classification_report(y_test_rs, y_pred_rs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       603
#            1       0.76      0.72      0.74       620
#
#     accuracy                           0.74      1223
#    macro avg       0.75      0.75      0.74      1223
# weighted avg       0.75      0.74      0.74      1223

# %% [markdown]
# ***Model With Random Over Sample Data***

# %%
classifier_ro = RandomForestClassifier(n_estimators=100, random_state=42)
classifier_ro.fit(x_train_ro, y_train_ro)
y_pred_ro = classifier_ro.predict(x_test_ro)

# %%
confusion_matrix(y_test_ro, y_pred_ro)
# Out:
# array([[2175,  251],
#        [  53, 2299]])

# %%
print(classification_report(y_test_ro, y_pred_ro)) # High Accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.93      2426
#            1       0.90      0.98      0.94      2352
#
#     accuracy                           0.94      4778
#    macro avg       0.94      0.94      0.94      4778
# weighted avg       0.94      0.94      0.94      4778

# %%
results_high_accuracy_models={'SVM':89,'LogisticRegression':82,'DecisionTreeClassifier':86,'RandomForestClassifier':94}

# %%
model_names = list(results_high_accuracy_models.keys())
accuracies = list(results_high_accuracy_models.values())

plt.figure(figsize=(10, 6))
plt.bar(model_names, accuracies, color='skyblue')
plt.xlabel('Models')
plt.ylabel('Accuracies')
plt.title('Accuracy of High-Performance Models')
plt.ylim(0, 100)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ***Based on the accuracies and considering both Type 1 and Type 2 errors, the Random Forest classifier emerges as the most suitable model for this dataset.***
